# %%
import os
import pandas as pd
from pandasai import PandasAI
from pandasai.llm.openai import OpenAI
import matplotlib.pyplot as plt 
# from pandasai import SmartDataframe


openai_api_key = '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'

llm = OpenAI(api_token=openai_api_key)

pandas_ai = PandasAI(llm)


df = pd.read_csv("pays_pauvres_prot.csv", index_col=0)
df.head(3)
# Out:
# /home/utilisateur/.local/lib/python3.10/site-packages/pandasai/__init__.py:147: UserWarning: `PandasAI` (class) is deprecated since v1.0 and will be removed in a future release. Please use `SmartDataframe` instead.
#   warnings.warn(
#                             Domain  Area Code (M49)                      Area  \
# Domain Code
# FBS          Food Balances (2010-)                4               Afghanistan
# FBS          Food Balances (2010-)                4               Afghanistan
# FBS          Food Balances (2010-)              140  Central African Republic
#
#              Element Code                                 Element  \
# Domain Code
# FBS                   674  Protein supply quantity (g/capita/day)
# FBS                   674  Protein supply quantity (g/capita/day)
# FBS                   674  Protein supply quantity (g/capita/day)
#
#             Item Code (FBS)              Item  Year Code  Year     Unit  \
# Domain Code
# FBS                   S2903  Vegetal Products       2021  2021  g/cap/d
# FBS                   S2941   Animal Products       2021  2021  g/cap/d
# FBS                   S2903  Vegetal Products       2021  2021  g/cap/d
#
#              Value Flag Flag Description
# Domain Code
# FBS          50.22    E  Estimated value
# FBS          10.48    E  Estimated value
# FBS          29.84    E  Estimated value

# %%
pandas_ai.run(df, prompt= 'quel est le pays où il y ale moins de value')
